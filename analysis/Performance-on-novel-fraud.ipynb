# %% [markdown]
# # Novel Fraud Analysis
# We show that hybrid model with exploration detects novel frauds better (e.g., trades from new HS6 and new import ID)

# %%
import numpy as np
import pandas as pd
import glob 
import csv
import traceback
import datetime
import os
pd.options.display.max_columns=50

# %% [markdown]
# ### Basic statistics and Novel fraud statistics
#
# Number of test weeks:
# * dfm: 196 weeks
# * dfn: 257 weeks
# * dft: 257 weeks
# * dfs: 48 weeks

# %%
def firstCheck(df):
    """ Sorting and indexing necessary for data preparation """
    df = df.dropna(subset=["illicit"])
    df = df.sort_values("sgd.date")
    df = df.reset_index(drop=True)
    return df

dfn = firstCheck(pd.read_csv('../data/ndata.csv'))
dft = firstCheck(pd.read_csv('../data/tdata.csv'))
dfm = firstCheck(pd.read_csv('../data/mdata.csv'))
dfs = firstCheck(pd.read_csv('../data/synthetic-imports-declarations.csv'))

# %%
for df in [dfm, dfn, dft]:
    print(df['importer.id'].nunique(), df['tariff.code'].nunique(), df['country'].nunique())
# Out:
# 40543 1916 149
# 165202 5953 229
# 132893 13387 195

# %% [markdown]
# #### Average illicit rates

# %%
# Malawi

date_begin = '20130101'
test_length = 7

start_day = datetime.date(int(date_begin[:4]), int(date_begin[4:6]), int(date_begin[6:8]))
period = datetime.timedelta(days=test_length)    
end_day = start_day + datetime.timedelta(days=test_length)    

old_IID = set()
new_proportions = []

avg_illicit_rates_m = []
num_trades_m = []

for week in range(208):
    weekly_trade = dfm[(dfm['sgd.date'] < end_day.strftime('%y-%m-%d')) & (dfm['sgd.date'] >= start_day.strftime('%y-%m-%d'))]
    start_day = end_day
    end_day = start_day + datetime.timedelta(days=test_length)
    avg_illicit_rates_m.append(np.mean(weekly_trade['illicit']))
    num_trades_m.append(len(weekly_trade))

# %%
import matplotlib.pyplot as plt
% matplotlib inline
# Out:
# UsageError: Line magic function `%` not found.

# %%
avg_illicit_rates_m = avg_illicit_rates_m[:-13]

# %%
plt.style.use('seaborn-whitegrid')
f = plt.figure()
plt.plot(pd.Series(avg_illicit_rates_m).rolling(4).mean())
plt.title('Country M', fontsize=25)
plt.xlabel('Year', fontsize=25)
plt.ylabel('Illicit rate', fontsize=25)
plt.xticks(ticks=[0,51,103,155,207], labels=['2013', 14, 15, 16,17], fontsize=25)
f.savefig("illicit_rate_m.pdf", bbox_inches='tight')

# %%
plt.style.use('seaborn-whitegrid')
f = plt.figure()
plt.plot(pd.Series(num_trades_m).rolling(4).mean())
plt.title('Country M', fontsize=25)
plt.xlabel('Year', fontsize=25)
plt.ylabel('# of weekly trades', fontsize=25)
plt.xticks(ticks=[0,51,103,155,207], labels=['2013', 14, 15, 16,17], fontsize=25)
f.savefig("num_weekly_trades_m.pdf", bbox_inches='tight')

# %%
# Nigeria

date_begin = '20130101'
test_length = 7

start_day = datetime.date(int(date_begin[:4]), int(date_begin[4:6]), int(date_begin[6:8]))
period = datetime.timedelta(days=test_length)    
end_day = start_day + datetime.timedelta(days=test_length)    

old_IID = set()
new_proportions = []

avg_illicit_rates_n = []
num_trades_n = []
for week in range(260):
    weekly_trade = dfn[(dfn['sgd.date'] < end_day.strftime('%y-%m-%d')) & (dfn['sgd.date'] >= start_day.strftime('%y-%m-%d'))]
    start_day = end_day
    end_day = start_day + datetime.timedelta(days=test_length)
    avg_illicit_rates_n.append(np.mean(weekly_trade['illicit']))
    num_trades_n.append(len(weekly_trade))

# %%
plt.style.use('seaborn-whitegrid')
f = plt.figure()
plt.plot(pd.Series(avg_illicit_rates_n).rolling(4).mean())
plt.title('Country N', fontsize=25)
plt.xlabel('Year', fontsize=25)
plt.ylabel('Illicit rate', fontsize=25)
plt.xticks(ticks=[0,51,103,155,207,259], labels=['2013', 14, 15, 16, 17, 18])
f.savefig("illicit_rate_n.pdf", bbox_inches='tight')

# %%
plt.style.use('seaborn-whitegrid')
f = plt.figure()
plt.plot(pd.Series(num_trades_n).rolling(4).mean())
plt.title('Country N', fontsize=25)
plt.xlabel('Year', fontsize=25)
plt.ylabel('# of weekly trades', fontsize=25)
plt.xticks(ticks=[0,51,103,155,207,259], labels=['2013', 14, 15, 16, 17, 18])
f.savefig("num_weekly_trades_n.pdf", bbox_inches='tight')

# %%
# Tunisia

date_begin = '20150101'
test_length = 7

start_day = datetime.date(int(date_begin[:4]), int(date_begin[4:6]), int(date_begin[6:8]))
period = datetime.timedelta(days=test_length)    
end_day = start_day + datetime.timedelta(days=test_length)    

old_IID = set()
new_proportions = []

avg_illicit_rates_t = []
num_trades_t = []
for week in range(260):
    weekly_trade = dft[(dft['sgd.date'] < end_day.strftime('%y-%m-%d')) & (dft['sgd.date'] >= start_day.strftime('%y-%m-%d'))]
    start_day = end_day
    end_day = start_day + datetime.timedelta(days=test_length)
    avg_illicit_rates_t.append(np.mean(weekly_trade['illicit']))
    num_trades_t.append(len(weekly_trade))

# %%
plt.style.use('seaborn-whitegrid')
f = plt.figure()
plt.plot(pd.Series(avg_illicit_rates_t).rolling(4).mean())
plt.title('Country T', fontsize=25)
plt.xlabel('Year', fontsize=25)
plt.ylabel('Illicit rate', fontsize=25)
plt.xticks(ticks=[0,51,103,155,207,259], labels=['2015', 16, 17, 18, 19, 20])
f.savefig("illicit_rate_t.pdf", bbox_inches='tight')

# %%
plt.style.use('seaborn-whitegrid')
f = plt.figure()
plt.plot(pd.Series(num_trades_t).rolling(4).mean())
plt.title('Country T', fontsize=25)
plt.xlabel('Year', fontsize=25)
plt.ylabel('# of weekly trades', fontsize=25)
plt.xticks(ticks=[0,51,103,155,207,259], labels=['2013', 14, 15, 16, 17, 18])
f.savefig("num_weekly_trades_t.pdf", bbox_inches='tight')

# %%
results = glob.glob('../results/performances/fld7-result-*')   # quick- or www21- or fld-
list1, list2 = zip(*sorted(zip([os.stat(result).st_size for result in results], results)))

# %%
# Retrieving results
num_logs = len([i for i in list1 if i > 1000])
count= 0
summary = []
for i in range(1,num_logs+1):
    rslt = pd.read_csv(list2[-i])
    dic = rslt[['runID','data','sampling','subsamplings','numWeek','current_inspection_rate','test_start','test_end']].iloc[len(rslt)-1].to_dict()
    run_id = round(dic['runID'], 3)
    data = dic['data']
    subsamplings = dic['subsamplings'].replace('/','+')
    strategy = dic['sampling']
    cir = dic['current_inspection_rate']
    summary.append(dic)
summary = pd.DataFrame(summary)

# %%
# Index will be used later
summary[summary.data == 'real-t']
# Out:
#            runID    data       sampling subsamplings  numWeek  \
# 0   1.603007e+09  real-t         random            -      257
# 1   1.603009e+09  real-t         random            -      257
# 15  1.603009e+09  real-t  enhanced_bATE            -      127
# 16  1.603009e+09  real-t          badge            -      124
# 17  1.603009e+09  real-t           bATE            -      111
# 21  1.603007e+09  real-t  enhanced_bATE            -       39
# 22  1.603007e+09  real-t          badge            -       21
# 23  1.603007e+09  real-t           bATE            -       15
#
#     current_inspection_rate test_start  test_end
# 0                      10.0   19-12-29  20-01-05
# 1                      10.0   19-12-29  20-01-05
# 15                     10.0   17-07-02  17-07-09
# 16                     10.0   17-06-11  17-06-18
# 17                     10.0   17-03-12  17-03-19
# 21                     10.0   15-10-25  15-11-01
# 22                     10.0   15-06-21  15-06-28
# 23                     10.0   15-05-10  15-05-17

# %%
### Previous code
def performanceOnNovel(exp_a):
    run_id = round(exp_a['runID'], 3)
    strategy = exp_a['sampling']
    subsamplings = exp_a['subsamplings'].replace('/','+')
    cir = exp_a['current_inspection_rate']
    week = exp_a['numWeek']
    measure_start = 0
    measure_end = week
    novelty = {}
    old_IID = set()

   
    for week in range(measure_start,measure_end):
        filename = glob.glob(f'results/query_indices/{run_id}-{strategy}-{subsamplings}-*-scratch-week-{week}.csv')[0]
        with open(filename, "r") as f:
            reader = csv.reader(f, delimiter=",")
            expid = next(reader)[1]
            dataset = next(reader)[1]
            episode = next(reader)[1]
            start_day = next(reader)[1]
            end_day = next(reader)[1]

            start_day = datetime.date(int(start_day[:4]), int(start_day[5:7]), int(start_day[8:10])).strftime('%y-%m-%d')
            end_day = datetime.date(int(end_day[:4]), int(end_day[5:7]), int(end_day[8:10])).strftime('%y-%m-%d')

            if week == measure_start:
                if dataset == 'real-m':
                    df = dfm
                elif dataset == 'synthetic':
                    df = dfs
                elif dataset == 'real-n':
                    df = dfn
                elif dataset == 'real-t':
                    df = dft
                
            alldata = df[(df['sgd.date'] < end_day) & (df['sgd.date'] >= start_day)].loc[:, ['illicit', 'revenue', 'importer.id']]
            alldata = alldata[~alldata['importer.id'].isin(old_IID)]

            if alldata.empty:
                continue
            
            all_indices = []
            all_samps = ''
            
            while True:
                try:
                    indices = next(reader)
                    samp = indices[0]
                    indices = indices[1:]
                    indices = list(map(int, indices))
                    all_indices.extend(indices)
                    all_samps = all_samps + (samp + '-')
                except StopIteration:
                    break
            
            
            if week == measure_start:
                novelty[f'{all_samps}-pre'] = []
                novelty[f'{all_samps}-rec'] = []
                novelty[f'{all_samps}-rev'] = []

            chosen = df.iloc[all_indices].loc[:, ['illicit', 'revenue', 'importer.id']]
            chosen = chosen[~chosen['importer.id'].isin(old_IID)]

            # Recall and revenue
            try:
                pre = sum(chosen['illicit'])/chosen['illicit'].count()
                rec = sum(chosen['illicit'])/sum(alldata['illicit'])
                rev = sum(chosen['revenue'])/sum(alldata['revenue'])
            except:
                continue
                
            novelty[f'{all_samps}-pre'].append(pre)
            novelty[f'{all_samps}-rec'].append(rec)
            novelty[f'{all_samps}-rev'].append(rev)

            old_IID = old_IID.union(set(alldata['importer.id'].values))
            print(f'# indices = {len(all_indices)}, # old_ID: {len(old_IID)}, # new trades: {len(chosen)}')
    return pd.DataFrame(novelty)

# %%
exp1, exp2, exp3, exp4, exp5 = 18, 23, 32, 38, 44
rival1 = performanceOnNovel(summary.loc[exp1])
print('!!!!!!!')
rival2 = performanceOnNovel(summary.loc[exp2])
print('!!!!!!!')
rival3 = performanceOnNovel(summary.loc[exp3])
print('!!!!!!!')
rival4 = performanceOnNovel(summary.loc[exp4])
print('!!!!!!!')
rival5 = performanceOnNovel(summary.loc[exp5])
# Out:
# # indices = 7037, # old_ID: 3125, # new trades: 7037
# # indices = 8219, # old_ID: 6130, # new trades: 4540
# # indices = 6273, # old_ID: 8365, # new trades: 2823
# # indices = 5303, # old_ID: 10165, # new trades: 2090
# # indices = 5316, # old_ID: 12275, # new trades: 2163
# # indices = 4548, # old_ID: 14127, # new trades: 1388
# # indices = 3316, # old_ID: 15720, # new trades: 986
# # indices = 3193, # old_ID: 17678, # new trades: 875
# # indices = 1219, # old_ID: 18408, # new trades: 591
# # indices = 844, # old_ID: 19409, # new trades: 209
# # indices = 926, # old_ID: 20690, # new trades: 220
# # indices = 956, # old_ID: 23039, # new trades: 178
# # indices = 737, # old_ID: 24641, # new trades: 74
# # indices = 1017, # old_ID: 26778, # new trades: 135
# # indices = 882, # old_ID: 28530, # new trades: 120
# # indices = 946, # old_ID: 30377, # new trades: 114
# # indices = 843, # old_ID: 32079, # new trades: 125
# # indices = 1020, # old_ID: 34015, # new trades: 105
# # indices = 1037, # old_ID: 36012, # new trades: 139
# # indices = 1005, # old_ID: 37878, # new trades: 149
# # indices = 845, # old_ID: 39225, # new trades: 97
# # indices = 995, # old_ID: 41056, # new trades: 141
# # indices = 966, # old_ID: 42649, # new trades: 119
# # indices = 1121, # old_ID: 44703, # new trades: 134
# # indices = 791, # old_ID: 45790, # new trades: 71
# # indices = 1094, # old_ID: 47562, # new trades: 143
# # indices = 776, # old_ID: 48647, # new trades: 46
# # indices = 997, # old_ID: 50173, # new trades: 86
# # indices = 969, # old_ID: 51434, # new trades: 109
# # indices = 1107, # old_ID: 53224, # new trades: 141
# # indices = 1099, # old_ID: 54814, # new trades: 110
# # indices = 1040, # old_ID: 56106, # new trades: 70
# # indices = 1092, # old_ID: 57400, # new trades: 101
# # indices = 1258, # old_ID: 58883, # new trades: 98
# # indices = 957, # old_ID: 59908, # new trades: 55
# # indices = 1306, # old_ID: 61636, # new trades: 94
# # indices = 665, # old_ID: 62433, # new trades: 63
# # indices = 1449, # old_ID: 64270, # new trades: 108
# # indices = 1096, # old_ID: 65527, # new trades: 96
# # indices = 1123, # old_ID: 66876, # new trades: 81
# # indices = 963, # old_ID: 67908, # new trades: 99
# # indices = 1281, # old_ID: 69395, # new trades: 103
# # indices = 1174, # old_ID: 70629, # new trades: 78
# # indices = 1301, # old_ID: 72324, # new trades: 159
# # indices = 1141, # old_ID: 73494, # new trades: 71
# # indices = 1176, # old_ID: 74572, # new trades: 83
# # indices = 829, # old_ID: 75380, # new trades: 86
# # indices = 862, # old_ID: 76238, # new trades: 70
# # indices = 1238, # old_ID: 77635, # new trades: 107
# # indices = 1056, # old_ID: 78634, # new trades: 84
# # indices = 1136, # old_ID: 79628, # new trades: 94
# # indices = 1107, # old_ID: 80633, # new trades: 57
# # indices = 961, # old_ID: 81468, # new trades: 78
# # indices = 1002, # old_ID: 82328, # new trades: 66
# # indices = 895, # old_ID: 82998, # new trades: 53
# # indices = 898, # old_ID: 83872, # new trades: 68
# # indices = 650, # old_ID: 84277, # new trades: 37
# # indices = 998, # old_ID: 85283, # new trades: 75
# # indices = 848, # old_ID: 86019, # new trades: 60
# # indices = 915, # old_ID: 86771, # new trades: 64
# # indices = 834, # old_ID: 87279, # new trades: 28
# # indices = 1124, # old_ID: 88249, # new trades: 85
# # indices = 909, # old_ID: 88857, # new trades: 48
# # indices = 700, # old_ID: 89357, # new trades: 40
# # indices = 959, # old_ID: 90123, # new trades: 78
# # indices = 929, # old_ID: 90693, # new trades: 66
# # indices = 839, # old_ID: 91273, # new trades: 66
# # indices = 1130, # old_ID: 92110, # new trades: 63
# # indices = 769, # old_ID: 92614, # new trades: 46
# # indices = 1086, # old_ID: 93496, # new trades: 73
# # indices = 863, # old_ID: 94027, # new trades: 44
# # indices = 1015, # old_ID: 94734, # new trades: 54
# # indices = 926, # old_ID: 95356, # new trades: 51
# # indices = 860, # old_ID: 95969, # new trades: 44
# # indices = 868, # old_ID: 96588, # new trades: 47
# # indices = 871, # old_ID: 97008, # new trades: 46
# # indices = 841, # old_ID: 97589, # new trades: 44
# # indices = 625, # old_ID: 98049, # new trades: 35
# # indices = 882, # old_ID: 98648, # new trades: 61
# # indices = 961, # old_ID: 99358, # new trades: 54
# # indices = 781, # old_ID: 99763, # new trades: 32
# # indices = 891, # old_ID: 100352, # new trades: 49
# # indices = 843, # old_ID: 100897, # new trades: 43
# # indices = 782, # old_ID: 101330, # new trades: 35
# # indices = 783, # old_ID: 101763, # new trades: 48
# # indices = 868, # old_ID: 102279, # new trades: 44
# # indices = 821, # old_ID: 102808, # new trades: 59
# # indices = 622, # old_ID: 103195, # new trades: 26
# # indices = 958, # old_ID: 103836, # new trades: 58
# # indices = 904, # old_ID: 104331, # new trades: 55
# # indices = 863, # old_ID: 104866, # new trades: 47
# # indices = 859, # old_ID: 105381, # new trades: 54
# # indices = 964, # old_ID: 106015, # new trades: 55
# # indices = 924, # old_ID: 106628, # new trades: 81
# # indices = 854, # old_ID: 107190, # new trades: 51
# # indices = 859, # old_ID: 107773, # new trades: 68
# # indices = 1053, # old_ID: 108445, # new trades: 72
# # indices = 1127, # old_ID: 109211, # new trades: 78
# # indices = 823, # old_ID: 109782, # new trades: 43
# # indices = 592, # old_ID: 110220, # new trades: 40
# # indices = 734, # old_ID: 110592, # new trades: 39
# # indices = 852, # old_ID: 111059, # new trades: 50
# # indices = 866, # old_ID: 111574, # new trades: 70
# # indices = 800, # old_ID: 112034, # new trades: 50
# # indices = 732, # old_ID: 112436, # new trades: 48
# # indices = 687, # old_ID: 112830, # new trades: 49
# # indices = 733, # old_ID: 113257, # new trades: 42
# # indices = 678, # old_ID: 113628, # new trades: 40
# # indices = 606, # old_ID: 113901, # new trades: 38
# # indices = 668, # old_ID: 114246, # new trades: 28
# # indices = 747, # old_ID: 114685, # new trades: 57
# # indices = 712, # old_ID: 115033, # new trades: 31
# # indices = 531, # old_ID: 115366, # new trades: 45
# # indices = 494, # old_ID: 115580, # new trades: 34
# # indices = 731, # old_ID: 115907, # new trades: 46
# # indices = 718, # old_ID: 116280, # new trades: 34
# # indices = 720, # old_ID: 116608, # new trades: 30
# # indices = 679, # old_ID: 116938, # new trades: 51
# # indices = 641, # old_ID: 117246, # new trades: 35
# # indices = 743, # old_ID: 117569, # new trades: 37
# # indices = 612, # old_ID: 117837, # new trades: 17
# # indices = 654, # old_ID: 118153, # new trades: 38
# # indices = 684, # old_ID: 118493, # new trades: 55
# # indices = 808, # old_ID: 118874, # new trades: 62
# # indices = 731, # old_ID: 119156, # new trades: 79
# # indices = 704, # old_ID: 119502, # new trades: 53
# # indices = 726, # old_ID: 119831, # new trades: 103
# # indices = 695, # old_ID: 120218, # new trades: 64
# # indices = 522, # old_ID: 120471, # new trades: 21
# # indices = 745, # old_ID: 120859, # new trades: 66
# # indices = 855, # old_ID: 121299, # new trades: 43
# # indices = 760, # old_ID: 121662, # new trades: 48
# # indices = 648, # old_ID: 121909, # new trades: 37
# # indices = 842, # old_ID: 122364, # new trades: 44
# # indices = 678, # old_ID: 122660, # new trades: 33
# # indices = 854, # old_ID: 123034, # new trades: 48
# # indices = 731, # old_ID: 123287, # new trades: 29
# # indices = 636, # old_ID: 123504, # new trades: 33
# # indices = 609, # old_ID: 123688, # new trades: 23
# # indices = 879, # old_ID: 124061, # new trades: 39
# # indices = 757, # old_ID: 124391, # new trades: 28
# # indices = 892, # old_ID: 124868, # new trades: 59
# # indices = 739, # old_ID: 125175, # new trades: 49
# # indices = 827, # old_ID: 125552, # new trades: 43
# # indices = 879, # old_ID: 125884, # new trades: 45
# # indices = 881, # old_ID: 126150, # new trades: 33
# # indices = 761, # old_ID: 126420, # new trades: 17
# # indices = 945, # old_ID: 126883, # new trades: 27
# # indices = 832, # old_ID: 127254, # new trades: 33
# # indices = 913, # old_ID: 127669, # new trades: 33
# # indices = 702, # old_ID: 128022, # new trades: 31
# # indices = 461, # old_ID: 128230, # new trades: 19
# # indices = 627, # old_ID: 128518, # new trades: 33
# # indices = 652, # old_ID: 128827, # new trades: 25
# # indices = 616, # old_ID: 129083, # new trades: 18
# # indices = 613, # old_ID: 129321, # new trades: 23
# # indices = 597, # old_ID: 129587, # new trades: 32
# # indices = 550, # old_ID: 129836, # new trades: 28
# # indices = 502, # old_ID: 130031, # new trades: 11
# # indices = 534, # old_ID: 130293, # new trades: 34
# # indices = 636, # old_ID: 130571, # new trades: 30
# # indices = 522, # old_ID: 130754, # new trades: 23
# # indices = 553, # old_ID: 131004, # new trades: 34
# # indices = 666, # old_ID: 131345, # new trades: 30
# # indices = 479, # old_ID: 131549, # new trades: 13
# # indices = 523, # old_ID: 131775, # new trades: 18
# # indices = 599, # old_ID: 132013, # new trades: 22
# # indices = 544, # old_ID: 132253, # new trades: 16
# # indices = 632, # old_ID: 132499, # new trades: 24
# # indices = 644, # old_ID: 132802, # new trades: 37
# # indices = 562, # old_ID: 133000, # new trades: 14
# # indices = 637, # old_ID: 133279, # new trades: 36
# # indices = 632, # old_ID: 133576, # new trades: 31
# # indices = 662, # old_ID: 133838, # new trades: 38
# # indices = 688, # old_ID: 134143, # new trades: 16
# # indices = 651, # old_ID: 134452, # new trades: 31
# # indices = 673, # old_ID: 134710, # new trades: 26
# # indices = 695, # old_ID: 134975, # new trades: 33
# # indices = 233, # old_ID: 135067, # new trades: 17
# # indices = 654, # old_ID: 135309, # new trades: 44
# # indices = 832, # old_ID: 135699, # new trades: 42
# # indices = 690, # old_ID: 135982, # new trades: 28
# # indices = 477, # old_ID: 136216, # new trades: 14
# # indices = 576, # old_ID: 136705, # new trades: 46
# # indices = 617, # old_ID: 137193, # new trades: 41
# # indices = 612, # old_ID: 137672, # new trades: 55
# # indices = 573, # old_ID: 138117, # new trades: 37
# # indices = 560, # old_ID: 138542, # new trades: 54
# # indices = 394, # old_ID: 138840, # new trades: 16
# # indices = 631, # old_ID: 139406, # new trades: 47
# # indices = 551, # old_ID: 139838, # new trades: 41
# # indices = 494, # old_ID: 140183, # new trades: 28
# # indices = 529, # old_ID: 140553, # new trades: 44
# # indices = 606, # old_ID: 141024, # new trades: 26
# # indices = 466, # old_ID: 141295, # new trades: 18
# # indices = 431, # old_ID: 141530, # new trades: 25
# # indices = 570, # old_ID: 141971, # new trades: 52
# # indices = 524, # old_ID: 142290, # new trades: 34
# # indices = 546, # old_ID: 142683, # new trades: 39
# # indices = 507, # old_ID: 142988, # new trades: 29
# # indices = 665, # old_ID: 143414, # new trades: 23
# # indices = 560, # old_ID: 143706, # new trades: 32
# # indices = 739, # old_ID: 144119, # new trades: 42
# # indices = 406, # old_ID: 144318, # new trades: 20
# # indices = 415, # old_ID: 144597, # new trades: 20
# # indices = 375, # old_ID: 144846, # new trades: 30
# # indices = 547, # old_ID: 145140, # new trades: 33
# # indices = 361, # old_ID: 145343, # new trades: 15
# # indices = 293, # old_ID: 145494, # new trades: 14
# # indices = 578, # old_ID: 145832, # new trades: 28
# # indices = 434, # old_ID: 146114, # new trades: 43
# # indices = 387, # old_ID: 146367, # new trades: 28
# # indices = 380, # old_ID: 146659, # new trades: 16
# # indices = 546, # old_ID: 147045, # new trades: 36
# # indices = 410, # old_ID: 147354, # new trades: 26
# # indices = 461, # old_ID: 147694, # new trades: 28
# # indices = 445, # old_ID: 148037, # new trades: 26
# # indices = 467, # old_ID: 148290, # new trades: 30
# # indices = 654, # old_ID: 148792, # new trades: 49
# # indices = 303, # old_ID: 148949, # new trades: 10
# # indices = 501, # old_ID: 149274, # new trades: 19
# # indices = 441, # old_ID: 149473, # new trades: 27
# # indices = 636, # old_ID: 149818, # new trades: 42
# # indices = 644, # old_ID: 150207, # new trades: 37
# # indices = 578, # old_ID: 150607, # new trades: 35
# # indices = 419, # old_ID: 150801, # new trades: 15
# # indices = 567, # old_ID: 151117, # new trades: 32
# # indices = 432, # old_ID: 151328, # new trades: 22
# # indices = 711, # old_ID: 151683, # new trades: 38
# # indices = 371, # old_ID: 151865, # new trades: 14
# # indices = 763, # old_ID: 152386, # new trades: 51
# # indices = 632, # old_ID: 152756, # new trades: 44
# # indices = 473, # old_ID: 153013, # new trades: 32
# # indices = 572, # old_ID: 153354, # new trades: 35
# # indices = 558, # old_ID: 153756, # new trades: 44
# # indices = 679, # old_ID: 154199, # new trades: 53
# # indices = 476, # old_ID: 154436, # new trades: 31
# # indices = 574, # old_ID: 154734, # new trades: 36
# # indices = 760, # old_ID: 155153, # new trades: 52
# # indices = 534, # old_ID: 155451, # new trades: 49
# # indices = 715, # old_ID: 155848, # new trades: 47
# # indices = 575, # old_ID: 156111, # new trades: 32
# # indices = 556, # old_ID: 156356, # new trades: 15
# # indices = 670, # old_ID: 156705, # new trades: 49
# # indices = 745, # old_ID: 157093, # new trades: 42
# # indices = 607, # old_ID: 157389, # new trades: 24
# # indices = 577, # old_ID: 157615, # new trades: 38
# # indices = 385, # old_ID: 157743, # new trades: 17
# # indices = 393, # old_ID: 157886, # new trades: 17
# # indices = 354, # old_ID: 158010, # new trades: 22
# # indices = 564, # old_ID: 158366, # new trades: 35
# # indices = 470, # old_ID: 158615, # new trades: 26
# # indices = 593, # old_ID: 158928, # new trades: 26
# # indices = 769, # old_ID: 159414, # new trades: 60
# # indices = 810, # old_ID: 159908, # new trades: 55
# # indices = 351, # old_ID: 160101, # new trades: 23
# # indices = 78, # old_ID: 160146, # new trades: 4
# !!!!!!!
# # indices = 7037, # old_ID: 3125, # new trades: 7037
# # indices = 8219, # old_ID: 6130, # new trades: 4542
# # indices = 6273, # old_ID: 8365, # new trades: 2796
# # indices = 5303, # old_ID: 10165, # new trades: 2089
# # indices = 5316, # old_ID: 12275, # new trades: 2021
# # indices = 4548, # old_ID: 14127, # new trades: 1532
# # indices = 3316, # old_ID: 15720, # new trades: 1029
# # indices = 3193, # old_ID: 17678, # new trades: 991
# # indices = 1219, # old_ID: 18408, # new trades: 525
# # indices = 844, # old_ID: 19409, # new trades: 231
# # indices = 926, # old_ID: 20690, # new trades: 280
# # indices = 956, # old_ID: 23039, # new trades: 189
# # indices = 737, # old_ID: 24641, # new trades: 83
# # indices = 1017, # old_ID: 26778, # new trades: 135
# # indices = 882, # old_ID: 28530, # new trades: 94
# # indices = 946, # old_ID: 30377, # new trades: 106
# # indices = 843, # old_ID: 32079, # new trades: 106
# # indices = 1020, # old_ID: 34015, # new trades: 153
# # indices = 1037, # old_ID: 36012, # new trades: 135
# # indices = 1005, # old_ID: 37878, # new trades: 125
# # indices = 845, # old_ID: 39225, # new trades: 115
# # indices = 995, # old_ID: 41056, # new trades: 167
# # indices = 966, # old_ID: 42649, # new trades: 139
# # indices = 1121, # old_ID: 44703, # new trades: 134
# # indices = 791, # old_ID: 45790, # new trades: 71
# # indices = 1094, # old_ID: 47562, # new trades: 136
# # indices = 776, # old_ID: 48647, # new trades: 40
# # indices = 997, # old_ID: 50173, # new trades: 89
# # indices = 969, # old_ID: 51434, # new trades: 90
# # indices = 1107, # old_ID: 53224, # new trades: 102
# # indices = 1099, # old_ID: 54814, # new trades: 112
# # indices = 1040, # old_ID: 56106, # new trades: 91
# # indices = 1092, # old_ID: 57400, # new trades: 94
# # indices = 1258, # old_ID: 58883, # new trades: 95
# # indices = 957, # old_ID: 59908, # new trades: 62
# # indices = 1306, # old_ID: 61636, # new trades: 129
# # indices = 665, # old_ID: 62433, # new trades: 62
# # indices = 1449, # old_ID: 64270, # new trades: 125
# # indices = 1096, # old_ID: 65527, # new trades: 81
# # indices = 1123, # old_ID: 66876, # new trades: 93
# # indices = 963, # old_ID: 67908, # new trades: 84
# # indices = 1281, # old_ID: 69395, # new trades: 113
# # indices = 1174, # old_ID: 70629, # new trades: 78
# # indices = 1301, # old_ID: 72324, # new trades: 155
# # indices = 1141, # old_ID: 73494, # new trades: 83
# # indices = 1176, # old_ID: 74572, # new trades: 109
# # indices = 829, # old_ID: 75380, # new trades: 71
# # indices = 862, # old_ID: 76238, # new trades: 72
# # indices = 1238, # old_ID: 77635, # new trades: 109
# # indices = 1056, # old_ID: 78634, # new trades: 70
# # indices = 1136, # old_ID: 79628, # new trades: 82
# # indices = 1107, # old_ID: 80633, # new trades: 53
# # indices = 961, # old_ID: 81468, # new trades: 70
# # indices = 1002, # old_ID: 82328, # new trades: 66
# # indices = 895, # old_ID: 82998, # new trades: 47
# # indices = 898, # old_ID: 83872, # new trades: 78
# # indices = 650, # old_ID: 84277, # new trades: 34
# # indices = 998, # old_ID: 85283, # new trades: 70
# # indices = 848, # old_ID: 86019, # new trades: 69
# # indices = 915, # old_ID: 86771, # new trades: 72
# # indices = 834, # old_ID: 87279, # new trades: 34
# # indices = 1124, # old_ID: 88249, # new trades: 71
# # indices = 909, # old_ID: 88857, # new trades: 58
# # indices = 700, # old_ID: 89357, # new trades: 41
# # indices = 959, # old_ID: 90123, # new trades: 45
# # indices = 929, # old_ID: 90693, # new trades: 92
# # indices = 839, # old_ID: 91273, # new trades: 63
# # indices = 1130, # old_ID: 92110, # new trades: 83
# # indices = 769, # old_ID: 92614, # new trades: 50
# # indices = 1086, # old_ID: 93496, # new trades: 65
# # indices = 863, # old_ID: 94027, # new trades: 43
# # indices = 1015, # old_ID: 94734, # new trades: 57
# # indices = 926, # old_ID: 95356, # new trades: 50
# # indices = 860, # old_ID: 95969, # new trades: 47
# # indices = 868, # old_ID: 96588, # new trades: 42
# # indices = 871, # old_ID: 97008, # new trades: 40
# # indices = 841, # old_ID: 97589, # new trades: 31
# # indices = 625, # old_ID: 98049, # new trades: 32
# # indices = 882, # old_ID: 98648, # new trades: 54
# # indices = 961, # old_ID: 99358, # new trades: 65
# # indices = 781, # old_ID: 99763, # new trades: 41
# # indices = 891, # old_ID: 100352, # new trades: 49
# # indices = 843, # old_ID: 100897, # new trades: 45
# # indices = 782, # old_ID: 101330, # new trades: 35
# # indices = 783, # old_ID: 101763, # new trades: 44
# # indices = 868, # old_ID: 102279, # new trades: 43
# # indices = 821, # old_ID: 102808, # new trades: 53
# # indices = 622, # old_ID: 103195, # new trades: 31
# # indices = 958, # old_ID: 103836, # new trades: 53
# # indices = 904, # old_ID: 104331, # new trades: 55
# # indices = 863, # old_ID: 104866, # new trades: 58
# # indices = 859, # old_ID: 105381, # new trades: 66
# # indices = 964, # old_ID: 106015, # new trades: 70
# # indices = 924, # old_ID: 106628, # new trades: 69
# # indices = 854, # old_ID: 107190, # new trades: 48
# # indices = 859, # old_ID: 107773, # new trades: 66
# # indices = 1053, # old_ID: 108445, # new trades: 65
# # indices = 1127, # old_ID: 109211, # new trades: 68
# # indices = 823, # old_ID: 109782, # new trades: 46
# # indices = 592, # old_ID: 110220, # new trades: 47
# # indices = 734, # old_ID: 110592, # new trades: 40
# # indices = 852, # old_ID: 111059, # new trades: 61
# # indices = 866, # old_ID: 111574, # new trades: 52
# # indices = 800, # old_ID: 112034, # new trades: 34
# # indices = 732, # old_ID: 112436, # new trades: 37
# # indices = 687, # old_ID: 112830, # new trades: 32
# # indices = 733, # old_ID: 113257, # new trades: 48
# # indices = 678, # old_ID: 113628, # new trades: 46
# # indices = 606, # old_ID: 113901, # new trades: 40
# # indices = 668, # old_ID: 114246, # new trades: 36
# # indices = 747, # old_ID: 114685, # new trades: 66
# # indices = 712, # old_ID: 115033, # new trades: 31
# # indices = 531, # old_ID: 115366, # new trades: 43
# # indices = 494, # old_ID: 115580, # new trades: 34
# # indices = 731, # old_ID: 115907, # new trades: 43
# # indices = 718, # old_ID: 116280, # new trades: 53
# # indices = 720, # old_ID: 116608, # new trades: 31
# # indices = 679, # old_ID: 116938, # new trades: 37
# # indices = 641, # old_ID: 117246, # new trades: 52
# # indices = 743, # old_ID: 117569, # new trades: 32
# # indices = 612, # old_ID: 117837, # new trades: 26
# # indices = 654, # old_ID: 118153, # new trades: 36
# # indices = 684, # old_ID: 118493, # new trades: 85
# # indices = 808, # old_ID: 118874, # new trades: 78
# # indices = 731, # old_ID: 119156, # new trades: 81
# # indices = 704, # old_ID: 119502, # new trades: 74
# # indices = 726, # old_ID: 119831, # new trades: 109
# # indices = 695, # old_ID: 120218, # new trades: 53
# # indices = 522, # old_ID: 120471, # new trades: 23
# # indices = 745, # old_ID: 120859, # new trades: 69
# # indices = 855, # old_ID: 121299, # new trades: 45
# # indices = 760, # old_ID: 121662, # new trades: 55
# # indices = 648, # old_ID: 121909, # new trades: 30
# # indices = 842, # old_ID: 122364, # new trades: 42
# # indices = 678, # old_ID: 122660, # new trades: 32
# # indices = 854, # old_ID: 123034, # new trades: 47
# # indices = 731, # old_ID: 123287, # new trades: 30
# # indices = 636, # old_ID: 123504, # new trades: 22
# # indices = 609, # old_ID: 123688, # new trades: 18
# # indices = 879, # old_ID: 124061, # new trades: 40
# # indices = 757, # old_ID: 124391, # new trades: 33
# # indices = 892, # old_ID: 124868, # new trades: 56
# # indices = 739, # old_ID: 125175, # new trades: 52
# # indices = 827, # old_ID: 125552, # new trades: 41
# # indices = 879, # old_ID: 125884, # new trades: 34
# # indices = 881, # old_ID: 126150, # new trades: 30
# # indices = 761, # old_ID: 126420, # new trades: 28
# # indices = 945, # old_ID: 126883, # new trades: 33
# # indices = 832, # old_ID: 127254, # new trades: 30
# # indices = 913, # old_ID: 127669, # new trades: 45
# # indices = 702, # old_ID: 128022, # new trades: 24
# # indices = 461, # old_ID: 128230, # new trades: 16
# # indices = 627, # old_ID: 128518, # new trades: 34
# # indices = 652, # old_ID: 128827, # new trades: 21
# # indices = 616, # old_ID: 129083, # new trades: 38
# # indices = 613, # old_ID: 129321, # new trades: 16
# # indices = 597, # old_ID: 129587, # new trades: 36
# # indices = 550, # old_ID: 129836, # new trades: 25
# # indices = 502, # old_ID: 130031, # new trades: 25
# # indices = 534, # old_ID: 130293, # new trades: 27
# # indices = 636, # old_ID: 130571, # new trades: 28
# # indices = 522, # old_ID: 130754, # new trades: 21
# # indices = 553, # old_ID: 131004, # new trades: 22
# # indices = 666, # old_ID: 131345, # new trades: 46
# # indices = 479, # old_ID: 131549, # new trades: 16
# # indices = 523, # old_ID: 131775, # new trades: 19
# # indices = 599, # old_ID: 132013, # new trades: 23
# # indices = 544, # old_ID: 132253, # new trades: 13
# # indices = 632, # old_ID: 132499, # new trades: 37
# # indices = 644, # old_ID: 132802, # new trades: 42
# # indices = 562, # old_ID: 133000, # new trades: 19
# # indices = 637, # old_ID: 133279, # new trades: 35
# # indices = 632, # old_ID: 133576, # new trades: 32
# # indices = 662, # old_ID: 133838, # new trades: 48
# # indices = 688, # old_ID: 134143, # new trades: 24
# # indices = 651, # old_ID: 134452, # new trades: 42
# # indices = 673, # old_ID: 134710, # new trades: 23
# # indices = 695, # old_ID: 134975, # new trades: 44
# # indices = 233, # old_ID: 135067, # new trades: 18
# # indices = 654, # old_ID: 135309, # new trades: 38
# # indices = 832, # old_ID: 135699, # new trades: 46
# # indices = 690, # old_ID: 135982, # new trades: 27
# # indices = 477, # old_ID: 136216, # new trades: 19
# # indices = 576, # old_ID: 136705, # new trades: 50
# # indices = 617, # old_ID: 137193, # new trades: 47
# # indices = 612, # old_ID: 137672, # new trades: 53
# # indices = 573, # old_ID: 138117, # new trades: 34
# # indices = 560, # old_ID: 138542, # new trades: 43
# # indices = 394, # old_ID: 138840, # new trades: 23
# # indices = 631, # old_ID: 139406, # new trades: 52
# # indices = 551, # old_ID: 139838, # new trades: 40
# # indices = 494, # old_ID: 140183, # new trades: 23
# # indices = 529, # old_ID: 140553, # new trades: 43
# # indices = 606, # old_ID: 141024, # new trades: 27
# # indices = 466, # old_ID: 141295, # new trades: 26
# # indices = 431, # old_ID: 141530, # new trades: 26
# # indices = 570, # old_ID: 141971, # new trades: 46
# # indices = 524, # old_ID: 142290, # new trades: 38
# # indices = 546, # old_ID: 142683, # new trades: 34
# # indices = 507, # old_ID: 142988, # new trades: 37
# # indices = 665, # old_ID: 143414, # new trades: 46
# # indices = 560, # old_ID: 143706, # new trades: 39
# # indices = 739, # old_ID: 144119, # new trades: 43
# # indices = 406, # old_ID: 144318, # new trades: 24
# # indices = 415, # old_ID: 144597, # new trades: 22
# # indices = 375, # old_ID: 144846, # new trades: 24
# # indices = 547, # old_ID: 145140, # new trades: 35
# # indices = 361, # old_ID: 145343, # new trades: 20
# # indices = 293, # old_ID: 145494, # new trades: 15
# # indices = 578, # old_ID: 145832, # new trades: 31
# # indices = 434, # old_ID: 146114, # new trades: 48
# # indices = 387, # old_ID: 146367, # new trades: 27
# # indices = 380, # old_ID: 146659, # new trades: 22
# # indices = 546, # old_ID: 147045, # new trades: 38
# # indices = 410, # old_ID: 147354, # new trades: 32
# # indices = 461, # old_ID: 147694, # new trades: 19
# # indices = 445, # old_ID: 148037, # new trades: 26
# # indices = 467, # old_ID: 148290, # new trades: 24
# # indices = 654, # old_ID: 148792, # new trades: 56
# # indices = 303, # old_ID: 148949, # new trades: 9
# # indices = 501, # old_ID: 149274, # new trades: 25
# # indices = 441, # old_ID: 149473, # new trades: 17
# # indices = 636, # old_ID: 149818, # new trades: 33
# # indices = 644, # old_ID: 150207, # new trades: 42
# # indices = 578, # old_ID: 150607, # new trades: 29
# # indices = 419, # old_ID: 150801, # new trades: 19
# # indices = 567, # old_ID: 151117, # new trades: 32
# # indices = 432, # old_ID: 151328, # new trades: 24
# # indices = 711, # old_ID: 151683, # new trades: 38
# # indices = 371, # old_ID: 151865, # new trades: 27
# # indices = 763, # old_ID: 152386, # new trades: 53
# # indices = 632, # old_ID: 152756, # new trades: 27
# # indices = 473, # old_ID: 153013, # new trades: 29
# # indices = 572, # old_ID: 153354, # new trades: 35
# # indices = 558, # old_ID: 153756, # new trades: 36
# # indices = 679, # old_ID: 154199, # new trades: 55
# # indices = 476, # old_ID: 154436, # new trades: 28
# # indices = 574, # old_ID: 154734, # new trades: 32
# # indices = 760, # old_ID: 155153, # new trades: 51
# # indices = 534, # old_ID: 155451, # new trades: 36
# # indices = 715, # old_ID: 155848, # new trades: 51
# # indices = 575, # old_ID: 156111, # new trades: 27
# # indices = 556, # old_ID: 156356, # new trades: 24
# # indices = 670, # old_ID: 156705, # new trades: 45
# # indices = 745, # old_ID: 157093, # new trades: 58
# # indices = 607, # old_ID: 157389, # new trades: 32
# # indices = 577, # old_ID: 157615, # new trades: 24
# # indices = 385, # old_ID: 157743, # new trades: 17
# # indices = 393, # old_ID: 157886, # new trades: 16
# # indices = 354, # old_ID: 158010, # new trades: 22
# # indices = 564, # old_ID: 158366, # new trades: 35
# # indices = 470, # old_ID: 158615, # new trades: 29
# # indices = 593, # old_ID: 158928, # new trades: 25
# # indices = 769, # old_ID: 159414, # new trades: 69
# # indices = 810, # old_ID: 159908, # new trades: 46
# # indices = 351, # old_ID: 160101, # new trades: 19
# # indices = 78, # old_ID: 160146, # new trades: 5
# !!!!!!!
# # indices = 7037, # old_ID: 3125, # new trades: 7037
# # indices = 8219, # old_ID: 6130, # new trades: 4543
# # indices = 6273, # old_ID: 8365, # new trades: 2832
# # indices = 5303, # old_ID: 10165, # new trades: 2089
# # indices = 5316, # old_ID: 12275, # new trades: 2116
# # indices = 4548, # old_ID: 14127, # new trades: 1384
# # indices = 3316, # old_ID: 15720, # new trades: 895

# %%
# Compare DATE performances: Between two experiments
plt.figure()
r1 = rival1['DATE-enhanced_bATE--rev'].rolling(window=14).mean()
r2 = rival2['DATE-random--rev'].rolling(window=14).mean()
r3 = rival3['DATE-badge--rev'].rolling(window=14).mean()
r4 = rival4['DATE-bATE--rev'].rolling(window=14).mean()
r5 = rival5['DATE--rev'].rolling(window=14).mean()

plt.plot(r1.index, r1, label=summary.loc[exp1]['data']+'-'+summary.loc[exp1]['subsamplings'])
plt.plot(r2.index, r2, label=summary.loc[exp2]['data']+'-'+summary.loc[exp2]['subsamplings'])
plt.plot(r3.index, r3, label=summary.loc[exp1]['data']+'-'+summary.loc[exp1]['subsamplings'])
plt.plot(r4.index, r4, label=summary.loc[exp2]['data']+'-'+summary.loc[exp2]['subsamplings'])
plt.plot(r5.index, r5, label=summary.loc[exp2]['data']+'-'+summary.loc[exp2]['subsamplings'])
plt.title('Compare performance for novel trade patterns')
plt.legend(loc='lower right')
plt.ylabel(var)
plt.xlabel('numWeeks')
plt.show()
plt.close()
