# %%
day = 20160701
! export CUDA_VISIBLE_DEVICES=3 && python main.py --data real-t --semi_supervised 0 --batch_size 128 --sampling pot --subsamplings xgb/random --weights 0/1 --mode scratch --train_from 20160101 --test_from $day --test_length 7 --valid_length 14 --initial_inspection_rate 20 --final_inspection_rate 5 --epoch 5 --closs bce --rloss full --save 0 --numweeks 100 --inspection_plan direct_decay
# Out:
# Experiment starts:  1627180154.476
# Namespace(act='relu', ada_lr=0.8, agg='sum', alpha=10, batch_size=128, closs='bce', data='real-t', device='0', devices=['0', '1', '2', '3'], dim=16, epoch=5, final_inspection_rate=5.0, fusion='concat', head_num=4, identifier='1627180154.476', initial_inspection_rate=20.0, inspection_plan='direct_decay', l2=0.01, lr=0.005, mode='scratch', numweeks=100, output='result-1627180154.476', rev_func='log', rloss='full', sampling='pot', save=0, semi_supervised=0, ssl_strategy='random', subsamplings='xgb/random', test_from='20160701', test_length=7, train_from='20160101', uncertainty='naive', use_self=1, valid_length=14, weights='0/1')
# Before masking:
#  0    410338
# 1     32531
# Name: illicit, dtype: int64
# Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# NumExpr defaulting to 8 threads.
# After masking:
#  0.0    82090
# 1.0     6484
# Name: illicit, dtype: int64
# ...
